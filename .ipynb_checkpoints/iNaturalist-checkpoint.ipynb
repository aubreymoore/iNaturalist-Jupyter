# %%
import requests
import matplotlib
import pandas as pd
from urllib.parse import urlencode
import json

pd.options.display.max_rows  = 1000
pd.options.display.max_columns = 1000

# %%
def getOrderFamily(taxon_id):
    url = 'https://api.inaturalist.org/v1/taxa/{}'.format(taxon_id)
    response = requests.get(url)
    j = json.loads(response.text)       
    
    order = ''
    family = ''
    for ancestor in j['results'][0]['ancestors']:
        if ancestor['rank'] == 'order':
            order = ancestor['name']
        if ancestor['rank'] == 'family':
            family = ancestor['name']
    return '{}: {}'.format(order, family)

#getOrderFamily(358893)

# %%
# Helpful site: https://api.inaturalist.org/v1/docs/#!/Observations/get_observations
# look for the taxon ids and place ids in the urls on the web site.

q = {
    #'project_id': 'insects-of-micronesia',
    'd1': '2019-08-01',
    'd2': '2019-12-31',
    'user_login': 'thomascamacho',
    'per_page': 200,
}

url = "https://api.inaturalist.org/v1/observations?"

df = pd.DataFrame()

page = 1
while True:
    q['page'] = page
    r = requests.get(url, params = q)
    
    results = r.json()["results"]
    df = pd.concat([df, pd.DataFrame(r.json()["results"])])

    if r.json()["results"] == []:
        print("no more results, stopping")
        break
    if page > 999:
        break
        
    if page == 1:
        num_pages = int(r.json()["total_results"] / r.json()["per_page"])+1
        print(r.json()["total_results"])
        print(num_pages)
        print("Results:", r.json()["total_results"], ", ", num_pages, " pages total")
    print("Retrieving page ", page)
    page += 1
# Out:
# 23
# 1
# Results: 23 ,  1  pages total
# Retrieving page  1
# no more results, stopping

# %%
# The 'user' column contains dicts.
# The following expands these dicts into columns and then drops the original column

df = pd.concat([df.drop(['user'], axis=1), df['user'].apply(pd.Series)], axis=1)

# The 'taxon' column contains dicts.
# The following expands these dicts into columns and then drops the original column

df = pd.concat([df.drop(['taxon'], axis=1), df['taxon'].apply(pd.Series)], axis=1)

# Unfortunately, we end up with multiple columns with identical names
# The following renamer class fixes this.

class renamer():
    
    def __init__(self):
        self.d = dict()

    def __call__(self, x):
        if x not in self.d:
            self.d[x] = 0
            return x
        else:
            self.d[x] += 1
        return "%s_%d" % (x, self.d[x])

df = df.rename(columns=renamer())

# %%
# lookup Order and Family

df['order_family'] = df['id_2'].apply(getOrderFamily)
# Out:
# 0      Lepidoptera: Nymphalidae
# 1                            :
# 2                            :
# 3     Coleoptera: Coccinellidae
# 4      Coleoptera: Scarabaeidae
# 5      Coleoptera: Scarabaeidae
# 6         Odonata: Libellulidae
# 7          Blattodea: Blattidae
# 8         Odonata: Libellulidae
# 9     Orthoptera: Tettigoniidae
# 10        Hemiptera: Rhopalidae
# 11                 Orthoptera:
# 12                 Orthoptera:
# 13    Orthoptera: Tettigoniidae
# 14        Hymenoptera: Vespidae
# 15                Hymenoptera:
# 16     Lepidoptera: Nymphalidae
# 17     Lepidoptera: Hesperiidae
# 18     Lepidoptera: Nymphalidae
# 19    Lepidoptera: Papilionidae
# 20        Lepidoptera: Pieridae
# 21     Lepidoptera: Nymphalidae
# 22                Hymenoptera:
# Name: id_2, dtype: object

# %%
print(df.dtypes)
# Out:
# annotations                           object
# cached_votes_total                     int64
# captive                                 bool
# comments                              object
# comments_count                         int64
# community_taxon_id                   float64
# context_geoprivacy                    object
# context_taxon_geoprivacy              object
# context_user_geoprivacy               object
# created_at                            object
# created_at_details                    object
# created_time_zone                     object
# description                           object
# faves                                 object
# faves_count                            int64
# flags                                 object
# geojson                               object
# geoprivacy                            object
# id                                     int64
# id_please                               bool
# ident_taxon_ids                       object
# identifications                       object
# identifications_count                  int64
# identifications_most_agree              bool
# identifications_most_disagree           bool
# identifications_some_agree              bool
# license_code                          object
# location                              object
# map_scale                             object
# mappable                                bool
# non_owner_ids                         object
# num_identification_agreements          int64
# num_identification_disagreements       int64
# oauth_application_id                   int64
# obscured                                bool
# observation_photos                    object
# observed_on                           object
# observed_on_details                   object
# observed_on_string                    object
# observed_time_zone                    object
# ofvs                                  object
# out_of_range                          object
# outlinks                              object
# owners_identification_from_vision     object
# photos                                object
# place_guess                           object
# place_ids                             object
# positional_accuracy                    int64
# preferences                           object
# project_ids                           object
# project_ids_with_curator_id           object
# project_ids_without_curator_id        object
# project_observations                  object
# public_positional_accuracy             int64
# quality_grade                         object
# quality_metrics                       object
# reviewed_by                           object
# site_id                                int64
# sounds                                object
# spam                                    bool
# species_guess                         object
# tags                                  object
# taxon_geoprivacy                      object
# time_observed_at                      object
# time_zone_offset                      object
# updated_at                            object
# uri                                   object
# uuid                                  object
# votes                                 object
# activity_count                         int64
# created_at_1                          object
# icon                                  object
# icon_url                              object
# id_1                                   int64
# identifications_count_1                int64
# journal_posts_count                    int64
# login                                 object
# login_autocomplete                    object
# login_exact                           object
# name                                  object
# name_autocomplete                     object
# observations_count                     int64
# orcid                                 object
# roles                                 object
# site_id_1                             object
# spam_1                                  bool
# suspended                               bool
# universal_search_rank                  int64
# ancestor_ids                          object
# ancestry                              object
# atlas_id                             float64
# complete_species_count               float64
# created_at_2                          object
# current_synonymous_taxon_ids          object
# default_photo                         object
# endemic                                 bool
# extinct                                 bool
# flag_counts                           object
# iconic_taxon_id                        int64
# iconic_taxon_name                     object
# id_2                                   int64
# introduced                              bool
# is_active                               bool
# min_species_ancestry                  object
# min_species_taxon_id                   int64
# name_1                                object
# native                                  bool
# observations_count_1                   int64
# parent_id                              int64
# preferred_common_name                 object
# rank                                  object
# rank_level                             int64
# taxon_changes_count                    int64
# taxon_schemes_count                    int64
# threatened                              bool
# universal_search_rank_1                int64
# wikipedia_url                         object
# complete_rank                         object
# dtype: object

# %%
df[['id', 'id_2', 'name', 'name_1', 'observed_on', 'location', 'place_guess', 'order_family']]
# Out:
#           id    id_2            name                   name_1 observed_on  \
# 0   36090342  358893  Thomas Camacho           Euploea eunice  2019-11-26
# 1   36048664   47792  Thomas Camacho                  Odonata  2019-11-25
# 2   35909225   47208  Thomas Camacho               Coleoptera  2019-11-21
# 3   35909199  319910  Thomas Camacho  Cheilomenes sexmaculata  2019-11-18
